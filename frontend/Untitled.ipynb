# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for Male and Female population by age groups and years
male_data = {
    "Year": [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
    "60-64": [611198, 609179, 615091, 621800, 628448, 637586, 649333, 661245, 677588, 697841, 711335],
    "65-69": [474253, 507807, 536807, 555428, 573231, 589110, 586717, 590148, 596905, 609962, 617714],
    "70-74": [357296, 370023, 381461, 398534, 416272, 436841, 470045, 499067, 518739, 540698, 554728],
    "75-79": [258411, 266730, 276169, 286700, 298086, 308155, 321453, 332909, 349419, 368497, 387887],
    "80-84": [190572, 192582, 194067, 196233, 197816, 202502, 209722, 218203, 227961, 239938, 249963],
    "85 and over": [139070, 147035, 155526, 163842, 171882, 179238, 184255, 189011, 194302, 200711, 208818]
}

female_data = {
    "Year": [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
    "60-64": [614802, 616525, 627944, 641390, 653717, 667305, 683115, 698364, 716369, 741684, 754125],
    "65-69": [480007, 514230, 542869, 562692, 583148, 603963, 608450, 619707, 633718, 652820, 662761],
    "70-74": [370375, 384453, 397916, 415752, 434039, 453355, 487660, 518600, 542683, 570355, 592099],
    "75-79": [299930, 304992, 311953, 321960, 332446, 343045, 354641, 364444, 379963, 399519, 419384],
    "80-84": [253460, 252511, 251378, 250715, 250321, 252601, 258711, 266308, 276040, 286797, 295455],
    "85 and over": [264537, 273490, 282232, 290292, 297063, 303441, 306607, 309746, 313427, 318504, 325410]
}

# Convert to DataFrame
df_male = pd.DataFrame(male_data)
df_female = pd.DataFrame(female_data)

# Plotting
plt.figure(figsize=(14, 8))

# Plot male population trends
for column in df_male.columns[1:]:
    plt.plot(df_male["Year"], df_male[column], marker='o', label=f"Male {column}")

# Plot female population trends
for column in df_female.columns[1:]:
    plt.plot(df_female["Year"], df_female[column], marker='s', linestyle='--', label=f"Female {column}")

# Customizing the plot
plt.title("Population Trends by Age Group (2011-2021)", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Population", fontsize=14)
plt.legend(title="Age Groups", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Data for Male and Female life expectancy trends in Australia
life_expectancy_data = {
    "Period": [
        "2010-2012", "2011-2013", "2012-2014", "2013-2015", "2014-2016",
        "2015-2017", "2016-2018", "2017-2019", "2018-2020", "2019-2021"
    ],
    "Male": [79.9, 80.1, 80.3, 80.4, 80.4, 80.5, 80.7, 80.9, 81.2, 81.3],
    "Female": [84.3, 84.3, 84.4, 84.5, 84.6, 84.6, 84.9, 85.0, 85.3, 85.4]
}

# Convert to DataFrame
df_life_expectancy = pd.DataFrame(life_expectancy_data)

# Plotting
plt.figure(figsize=(12, 6))

# Line plot for Male and Female life expectancy
plt.plot(df_life_expectancy["Period"], df_life_expectancy["Male"], marker='o', label="Male", color='blue')
plt.plot(df_life_expectancy["Period"], df_life_expectancy["Female"], marker='s', linestyle='--', label="Female", color='red')

# Customizing the plot
plt.title("Life Expectancy Trends in Australia (2010-2021)", fontsize=16)
plt.xlabel("Period", fontsize=14)
plt.ylabel("Life Expectancy (years)", fontsize=14)
plt.xticks(rotation=45)
plt.legend(title="Gender", loc='upper left')
plt.grid(True)
plt.tight_layout()

# Display the plot
plt.show()
